# %%
#!pip install pandas scikit-learn
#!pip install wordcloud


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score

# %%
dt = pd.read_csv('data test.csv') #data for the test check

# %%
data=pd.read_csv('data after nlp.csv')
data
# Out:
#                                                headline  \
# 0                        1919: The Year of the Crack-Up
# 1                         In Search of Lost Screen Time
# 2     Warren Wells, Star Receiver With a Derailed Ca...
# 3                          2019: The Year of the Wolves
# 4                        Why Trump Reigns as King Cyrus
# ...                                                 ...
# 3916  As Trump Demands His Wall, Lawmakers Plead for...
# 3917  U.S. Appears to Soften Timing for List of Nort...
# 3918  Dusan Makavejev, 86. Eyebrow-Raising Serbian D...
# 3919  A Year Into the Overlooked Project, Widening t...
# 3920        The Alarming Allure of Australia’s Brumbies
#
#                                                abstract  \
# 0     From the Treaty of Versailles to Prohibition, ...
# 1     Imagine what we could do with our money, and h...
# 2     Wells was a deep threat for the vaunted Oaklan...
# 3         Can the Constitution withstand the partisans?
# 4     The Christian right doesn’t like the president...
# ...                                                 ...
# 3916  Lawmakers reacted with concern and bewildermen...
# 3917  A top diplomat said the Trump administration m...
# 3918  His films, among them “WR: Mysteries of the Or...
# 3919  In the past year, The Times published obituari...
# 3920  The environment is being sacrificed for a nati...
#
#                                          lead paragraph  \
# 0     Throughout 2019, The New York Times Opinion se...
# 1     More than three-quarters of all Americans own ...
# 2     Warren Wells, a former wide receiver who becam...
# 3     In Willa Cather’s novel “My Antonia,” there ar...
# 4     The month before the 2018 midterms, a thousand...
# ...                                                 ...
# 3916  WASHINGTON — President Trump proclaimed on Thu...
# 3917  WASHINGTON — A top American diplomat signaled ...
# 3918  Dusan Makavejev, a Serbian director whose movi...
# 3919  Times Insider explains who we are and what we ...
# 3920  SYDNEY, Australia — Since this country’s found...
#
#                               first keyword    lead paragraph keywords  \
# 0     United States Politics and Government      throughout, 2019, new
# 1                               Smartphones    american, smartphone, 1
# 2                 Wells, Warren (1942-2018)       warren, well, former
# 3                           Trump, Donald J       pavel, willa, cather
# 4     United States Politics and Government         trump, month, 2018
# ...                                     ...                        ...
# 3916                        Border Barriers    border, lawmaker, would
# 3917  United States International Relations  washington, top, american
# 3918                       Makavejev, Dusan  dusan, makavejev, serbian
# 3919                        Women and Girls    time, insider, explains
# 3920                       Invasive Species   horse, sydney, australia
#
#      Main Keywords lead paragraph (tf- idf)  \
# 0                    centuri, follow, shape
# 1                       billion, wake, hour
# 2                         76, tex, beaumont
# 3                        pavel, emigr, came
# 4                      trump, presid, elect
# ...                                     ...
# 3916                  would, lawmak, border
# 3917                   pursu, trump, presid
# 3918                    86, serbia, belgrad
# 3919                  togeth, come, journal
# 3920                   hors, spirit, nation
#
#                       abstract keywords Main Keywords abstract (tf- idf)  \
# 0       treaty, versailles, prohibition             come, centuri, world
# 1                 imagine, could, money                year, asid, phone
# 2                    well, deep, threat      sentenc, prison, seasonlong
# 3     constitution, withstand, partisan   partisan, withstand, constitut
# 4                like, christian, right                like, style, judg
# ...                                 ...                              ...
# 3916          border, lawmaker, reacted       border, southwestern, wall
# 3917                top, diplomat, said           diplomaci, help, could
# 3918                    film, among, wr             revil, sometim, also
# 3919                   past, year, time            month, histori, black
# 3920  environment, sacrificed, national             myth, nation, sacrif
#
#                 headline keywords
# 0               1919, year, crack
# 1            search, lost, screen
# 2              warren, well, star
# 3                2019, year, wolf
# 4              trump, reign, king
# ...                           ...
# 3916          trump, demand, wall
# 3917           u, appears, soften
# 3918         dusan, makavejev, 86
# 3919    year, overlooked, project
# 3920  alarming, allure, australia
#
# [3921 rows x 9 columns]

# %%
df = data.copy()

# %% [markdown]
# # We will check the division by K MEANS for all the keywords that we extracted from each column in the previous steps

# %% [markdown]
# ## lead paragraph keywords

# %%
df['keywords'] = df['lead paragraph keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 35 # You can adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters        
silhouette_avg1 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", silhouette_avg1)
# Out:
# Silhouette Score: 0.11453115

# %%
wcss = []
for i in range(1, 30):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=29, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(20, 20))
plt.plot(range(1, 30), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %%
#It can be seen that after the 13th time the distances between the K numbers remain relatively the same.
#A test was also done with a higher K number and there does not seem to be stabilization even after about 100 times, therefore we decided to stop the division into K after the stabilization of the distance.

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["lead paragraph keywords"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# optimal K

# %%
df['keywords'] = df['lead paragraph keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 13 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters        
new_silhouette_avg1 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", new_silhouette_avg1)
# Out:
# Silhouette Score: 0.09561971

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["lead paragraph keywords"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split() 
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Main Keywords lead paragraph (tf- idf)

# %%
df['keywords'] = df['Main Keywords lead paragraph (tf- idf)'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 35 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]


df['cluster_label'] = clusters        
silhouette_avg2 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", silhouette_avg2)
# Out:
# Silhouette Score: 0.10390839

# %%
wcss = []
for i in range(1, 35):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=34, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(20, 20))
plt.plot(range(1, 35), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 35))
plt.grid(True)
plt.show()

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
#optimal K

# %%
df['keywords'] = df['Main Keywords lead paragraph (tf- idf)'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 11 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters        
new_silhouette_avg2 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", new_silhouette_avg2)
# Out:
# Silhouette Score: 0.077126846

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split() 
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## abstract keywords

# %%
df['keywords'] = df['abstract keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 35 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters        
silhouette_avg3 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", silhouette_avg3)
# Out:
# Silhouette Score: 0.042982604

# %%
wcss = []
for i in range(1, 30):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=29, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(20, 20))
plt.plot(range(1, 30), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %%
#It can be seen that after the 10th time the distances between the K numbers remain relatively the same.
#A test was also done with a higher K number and there does not seem to be stabilization even after about 100 times, therefore we decided to stop the division into K after the stabilization of the distance.

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["abstract keywords"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  

    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# optimal k

# %%
df['keywords'] = df['abstract keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters        
new_silhouette_avg3 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", new_silhouette_avg3)
# Out:
# Silhouette Score: 0.032840762

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["abstract keywords"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Main Keywords abstract (tf- idf)

# %%
df['keywords'] = df['Main Keywords abstract (tf- idf)'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 35
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters    
silhouette_avg4 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", silhouette_avg4)
# Out:
# Silhouette Score: 0.044803765

# %%
wcss = []
for i in range(1, 30):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=29, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(20, 20))
plt.plot(range(1, 30), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %%
# It can be seen that after the 11th time the distances between the K numbers remain relatively the same.

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
#optimal k

# %%
df['keywords'] = df['Main Keywords abstract (tf- idf)'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 11 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters    
new_silhouette_avg4 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", new_silhouette_avg4)
# Out:
# Silhouette Score: 0.035432994

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split() 
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## headline keywords

# %%
df['keywords'] = df['headline keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 35 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]


df['cluster_label'] = clusters    
silhouette_avg5 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", silhouette_avg5)
# Out:
# Silhouette Score: 0.03169619

# %%
wcss = []
for i in range(1, 30):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=29, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)
    
plt.figure(figsize=(20, 20))
plt.plot(range(1, 30), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %%
#It can be seen that after the 18th time the distances between the K numbers remain relatively the same.
#A test was also done with a higher K number and there does not seem to be stabilization even after about 100 times, therefore we decided to stop the division into K after the stabilization of the distance.

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split() 
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
#optimal k

# %%
df['keywords'] = df['headline keywords'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)

# %%
word2vec_model = Word2Vec(sentences=df['keywords'], vector_size=100, window=5, min_count=1, workers=4)

keyword_vectors = []
for row in df['keywords']:
    row_vectors = [word2vec_model.wv[keyword] for keyword in row if keyword in word2vec_model.wv]
    if row_vectors:
        row_mean_vector = np.mean(row_vectors, axis=0)
        keyword_vectors.append(row_mean_vector)

num_clusters = 18
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(keyword_vectors)
clusters = kmeans.labels_

keyword_cluster_mapping = {}
for i, row in enumerate(df['keywords']):
    for j, keyword in enumerate(row):
        keyword_cluster_mapping[keyword] = clusters[i]

df['cluster_label'] = clusters    
new_silhouette_avg5 = silhouette_score(keyword_vectors, clusters)
print("Silhouette Score:", new_silhouette_avg5)
# Out:
# Silhouette Score: 0.021315379

# %%
dt['cluster_label'] = df['cluster_label']

# %%
test =dt[['headline','cluster_label',"section name"]].groupby(['cluster_label',"section name"]).count()
test.sort_values(by='headline',ascending=False)

# %%
heatmap_data = dt.groupby(['cluster_label', 'section name']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Comparison between Cluster Labels and Section Names')
plt.xlabel('Section Name')
plt.ylabel('Cluster Label')
plt.show()

# %%
data['Category'] = dt["section name"]
data['Keyword'] = df["Main Keywords abstract (tf- idf)"]
df = pd.DataFrame(data)

category_keywords = {}

for index, row in df.iterrows():
    category = row['Category']
    keywords = row['Keyword'].split()  
    
    if category in category_keywords:
        category_keywords[category].extend(keywords)
    else:
        category_keywords[category] = keywords

fig, axes = plt.subplots(nrows=1, ncols=len(category_keywords), figsize=(100, 100))
for i, (category, keywords) in enumerate(category_keywords.items()):
    text = ' '.join(keywords)
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(f'Category {category}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## first keyword

# %%
data = df['first keyword']
data = data.dropna()

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data)

k = 35  
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
labels = kmeans.labels_


silhouette_avg6 = silhouette_score(X, labels)
print("Silhouette Score:", silhouette_avg6)
# Out:
# Silhouette Score: 0.3574538078688774

# %%
wcss = []
for i in range(1, 30):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=29, random_state=0)
    kmeans.fit(keyword_vectors)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(20, 20))
plt.plot(range(1, 30), wcss, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %%
# It can be seen that after the 16th time the distances between the K numbers remain relatively the same.

# %%
#optimal k

# %%
data = df['first keyword']
data = data.dropna()

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data)

k = 16  
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
labels = kmeans.labels_

new_silhouette_avg6 = silhouette_score(X, labels)
print("Silhouette Score:", new_silhouette_avg7)
# Out:
# Silhouette Score: 0.23816938987521075

# %% [markdown]
# ## Silhouette Score table (k=35)

# %%
Silhouette_Score_table = pd.DataFrame({
    'lead paragraph keywords': [silhouette_avg1],
    'Main Keywords lead paragraph (tf- idf)': [silhouette_avg2],
    'abstract keywords': [silhouette_avg3],
    'Main Keywords abstract (tf- idf)': [silhouette_avg4],
    'headline keywords': [silhouette_avg5],
    'first keyword': [silhouette_avg6],
})
Silhouette_Score_table
# Out:
#    lead paragraph keywords  Main Keywords lead paragraph (tf- idf)  \
# 0                 0.114531                                0.103908
#
#    abstract keywords  Main Keywords abstract (tf- idf)  headline keywords  \
# 0           0.042983                          0.044804           0.031696
#
#    first keyword
# 0       0.357454

# %% [markdown]
# ## Silhouette Score table (k=optimal)

# %%
Silhouette_Score_table_optimal = pd.DataFrame({
    'lead paragraph keywords': [new_silhouette_avg1],
    'Main Keywords lead paragraph (tf- idf)': [new_silhouette_avg2],
    'abstract keywords': [new_silhouette_avg3],
    'Main Keywords abstract (tf- idf)': [new_silhouette_avg4],
    'headline keywords': [new_silhouette_avg5],
    'first keyword': [new_silhouette_avg6],
})
Silhouette_Score_table_optimal
# Out:
#    lead paragraph keywords  Main Keywords lead paragraph (tf- idf)  \
# 0                  0.09562                                0.077127
#
#    abstract keywords  Main Keywords abstract (tf- idf)  headline keywords  \
# 0           0.032841                          0.035433           0.021315
#
#    first keyword
# 0       0.213794

# %%
#the only improvement is in TF_IDF columns.

# %%
#Main Keywords lead paragraph (tf- idf) Silhouette Score is the highiest but it is still low whice Indicates that some values may fall under a different category
